# %% [markdown]
# #### Checking Nasa_Power API connection

# %%
import pandas as pd 
import requests

# %%
def fetch_weather_data(lat: float, lon: float, start: str, end: str):
    url = "https://power.larc.nasa.gov/api/temporal/monthly/point"

    params = {
        "start":start,
        "end":end,
        "latitude":lat,
        "longitude":lon,
        "community":"AG",
        "parameters":"T2M,PRECTOTCORR,ALLSKY_SFC_SW_DWN",
        "format":"JSON",
        "header":"true"
        }
    response = requests.get(url=url, params=params)
    response.raise_for_status()

    # print(f"Requesting NASA POWER API:\n{response.url}\n")
    return response.json()

# %%
data = fetch_weather_data(lat=38.6274, lon=-90.1982, start=2021, end=2024)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['type', 'geometry', 'properties', 'header', 'messages', 'parameters', 'times'])

# %%
data
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-90.198, 38.627, 152.79]},
#  'properties': {'parameter': {'ALLSKY_SFC_SW_DWN': {'202101': 6.4,
#     '202102': 9.97,
#     '202103': 14.63,
#     '202104': 19.03,
#     '202105': 18.56,
#     '202106': 22.04,
#     '202107': 21.36,
#     '202108': 20.6,
#     '202109': 18.18,
#     '202110': 10.78,
#     '202111': 9.93,
#     '202112': 7.14,
#     '202113': 14.9,
#     '202201': 8.86,
#     '202202': 11.3,
#     '202203': 15.06,
#     '202204': 17.43,
#     '202205': 19.08,
#     '202206': 25.32,
#     '202207': 21.92,
#     '202208': 21.17,
#     '202209': 17.57,
#     '202210': 14.39,
#     '202211': 9.87,
#     '202212': 5.88,
#     '202213': 15.67,
#     '202301': 6.91,
#     '202302': 11.74,
#     '202303': 13.06,
#     '202304': 20.66,
#     '202305': 23.09,
#     '202306': 24.12,
#     '202307': 21.53,
#     '202308': 19.0,
#     '202309': 17.7,
#     '202310': 12.48,
#     '202311': 10.28,
#     '202312': 6.51,
#     '202313': 15.59,
#     '202401': 6.36,
#     '202402': 12.58,
#     '202403': 16.35,
#     '202404': 18.41,
#     '202405': 21.05,
#     '202406': 24.7,
#     '202407': 20.76,
#     '202408': 19.93,
#     '202409': 16.32,
#     '202410': 15.5,
#     '202411': 8.19,
#     '202412': 6.43,
#     '202413': 15.55},
#    'PRECTOTCORR': {'202101': 2.95,
#     '202102': 1.98,
#     '202103': 4.24,
#     '202104': 3.25,
#     '202105': 2.65,
#     '202106': 3.26,
#     '202107': 5.59,
#     '202108': 2.95,
#     '202109': 2.3,
#     '202110': 3.61,
#     '202111': 0.77,
#     '202112': 2.56,
#     '202113': 3.02,
#     '202201': 1.24,
#     '202202': 4.16,
#     '202203': 4.17,
#     '202204': 3.33,
#     '202205': 4.41,
#     '202206': 1.73,
#     '202207': 5.13,
#     '202208': 2.88,
#     '202209': 2.0,
#     '202210': 2.25,
#     '202211': 1.81,
#     '202212': 2.0,
#     '202213': 2.92,
#     '202301': 2.61,
#     '202302': 1.92,
#     '202303': 5.09,
#     '202304': 2.03,
#     '202305': 2.06,
#     '202306': 1.53,
#     '202307': 3.79,
#     '202308': 3.97,
#     '202309': 1.43,
#     '202310': 1.68,
#     '202311': 0.69,
#     '202312': 1.98,
#     '202313': 2.41,
#     '202401': 3.95,
#     '202402': 0.35,
#     '202403': 2.23,
#     '202404': 5.32,
#     '202405': 5.1,
#     '202406': 3.16,
#     '202407': 7.52,
#     '202408': 1.17,
#     '202409': 3.73,
#     '202410': 0.61,
#     '202411': 5.61,
#     '202412': 2.73,
#     '202413': 3.46},
#    'T2M': {'202101': -0.45,
#     '202102': -3.6,
#     '202103': 8.91,
#     '202104': 12.14,
#     '202105': 17.07,
#     '202106': 24.12,
#     '202107': 24.72,
#     '202108': 25.34,
#     '202109': 21.82,
#     '202110': 16.49,
#     '202111': 6.22,
#     '202112': 6.47,
#     '202113': 13.38,
#     '202201': -2.88,
#     '202202': -0.71,
#     '202203': 7.66,
#     '202204': 12.01,
#     '202205': 19.36,
#     '202206': 23.82,
#     '202207': 26.48,
#     '202208': 24.96,
#     '202209': 20.95,
#     '202210': 13.37,
#     '202211': 6.42,
#     '202212': 0.95,
#     '202213': 12.78,
#     '202301': 2.83,
#     '202302': 4.69,
#     '202303': 6.66,
#     '202304': 13.04,
#     '202305': 19.13,
#     '202306': 23.72,
#     '202307': 27.0,
#     '202308': 25.32,
#     '202309': 22.44,
#     '202310': 14.96,
#     '202311': 7.98,
#     '202312': 4.85,
#     '202313': 14.44,
#     '202401': -2.16,
#     '202402': 5.73,
#     '202403': 10.01,
#     '202404': 14.65,
#     '202405': 20.75,
#     '202406': 24.68,
#     '202407': 24.7,
#     '202408': 24.82,
#     '202409': 21.95,
#     '202410': 15.57,
#     '202411': 8.88,
#     '202412': 3.01,
#     '202413': 14.4}}},
#  'header': {'title': 'NASA/POWER Source Native Resolution Monthly and Annual',
#   'api': {'version': 'v2.8.1', 'name': 'POWER Monthly and Annual API'},
#   'sources': ['MERRA2', 'SYN1DEG'],
#   'fill_value': -999.0,
#   'time_standard': 'LST',
#   'start': '20210101',
#   'end': '20241231'},
#  'messages': [],
#  'parameters': {'ALLSKY_SFC_SW_DWN': {'units': 'MJ/m^2/day',
#    'longname': 'All Sky Surface Shortwave Downward Irradiance'},
#   'PRECTOTCORR': {'units': 'mm/day', 'longname': 'Precipitation Corrected'},
#   'T2M': {'units': 'C', 'longname': 'Temperature at 2 Meters'}},
#  'times': {'data': 7.169, 'process': 0.07}}

# %%
for i in data["parameters"].keys():
    print(i,":", data["parameters"][i]["units"])
# Out:
# ALLSKY_SFC_SW_DWN : MJ/m^2/day
# PRECTOTCORR : mm/day
# T2M : C

# %%
data["type"]
# Out:
# 'Feature'

# %%
data["geometry"]
# Out:
# {'type': 'Point', 'coordinates': [-90.198, 38.627, 152.79]}

# %%
data["header"]
# Out:
# {'title': 'NASA/POWER Source Native Resolution Monthly and Annual',
#  'api': {'version': 'v2.8.0', 'name': 'POWER Monthly and Annual API'},
#  'sources': ['MERRA2', 'SYN1DEG'],
#  'fill_value': -999.0,
#  'time_standard': 'LST',
#  'start': '20210101',
#  'end': '20241231'}

# %%
data["messages"]
# Out:
# []

# %%
data["parameters"]
# Out:
# {'ALLSKY_SFC_SW_DWN': {'units': 'MJ/m^2/day',
#   'longname': 'All Sky Surface Shortwave Downward Irradiance'},
#  'PRECTOTCORR': {'units': 'mm/day', 'longname': 'Precipitation Corrected'},
#  'T2M': {'units': 'C', 'longname': 'Temperature at 2 Meters'}}

# %%
data["properties"]
# Out:
# {'parameter': {'ALLSKY_SFC_SW_DWN': {'202101': 6.4,
#    '202102': 9.97,
#    '202103': 14.63,
#    '202104': 19.03,
#    '202105': 18.56,
#    '202106': 22.04,
#    '202107': 21.36,
#    '202108': 20.6,
#    '202109': 18.18,
#    '202110': 10.78,
#    '202111': 9.93,
#    '202112': 7.14,
#    '202113': 14.9,
#    '202201': 8.86,
#    '202202': 11.3,
#    '202203': 15.06,
#    '202204': 17.43,
#    '202205': 19.08,
#    '202206': 25.32,
#    '202207': 21.92,
#    '202208': 21.17,
#    '202209': 17.57,
#    '202210': 14.39,
#    '202211': 9.87,
#    '202212': 5.88,
#    '202213': 15.67,
#    '202301': 6.91,
#    '202302': 11.74,
#    '202303': 13.06,
#    '202304': 20.66,
#    '202305': 23.09,
#    '202306': 24.12,
#    '202307': 21.53,
#    '202308': 19.0,
#    '202309': 17.7,
#    '202310': 12.48,
#    '202311': 10.28,
#    '202312': 6.51,
#    '202313': 15.59,
#    '202401': 6.36,
#    '202402': 12.58,
#    '202403': 16.35,
#    '202404': 18.41,
#    '202405': 21.05,
#    '202406': 24.7,
#    '202407': 20.76,
#    '202408': 19.93,
#    '202409': 16.32,
#    '202410': 15.5,
#    '202411': 8.19,
#    '202412': 6.43,
#    '202413': 15.55},
#   'PRECTOTCORR': {'202101': 2.95,
#    '202102': 1.98,
#    '202103': 4.24,
#    '202104': 3.25,
#    '202105': 2.65,
#    '202106': 3.26,
#    '202107': 5.59,
#    '202108': 2.95,
#    '202109': 2.3,
#    '202110': 3.61,
#    '202111': 0.77,
#    '202112': 2.56,
#    '202113': 3.02,
#    '202201': 1.24,
#    '202202': 4.16,
#    '202203': 4.17,
#    '202204': 3.33,
#    '202205': 4.41,
#    '202206': 1.73,
#    '202207': 5.13,
#    '202208': 2.88,
#    '202209': 2.0,
#    '202210': 2.25,
#    '202211': 1.81,
#    '202212': 2.0,
#    '202213': 2.92,
#    '202301': 2.61,
#    '202302': 1.92,
#    '202303': 5.09,
#    '202304': 2.03,
#    '202305': 2.06,
#    '202306': 1.53,
#    '202307': 3.79,
#    '202308': 3.97,
#    '202309': 1.43,
#    '202310': 1.68,
#    '202311': 0.69,
#    '202312': 1.98,
#    '202313': 2.41,
#    '202401': 3.95,
#    '202402': 0.35,
#    '202403': 2.23,
#    '202404': 5.32,
#    '202405': 5.1,
#    '202406': 3.16,
#    '202407': 7.52,
#    '202408': 1.17,
#    '202409': 3.73,
#    '202410': 0.61,
#    '202411': 5.61,
#    '202412': 2.73,
#    '202413': 3.46},
#   'T2M': {'202101': -0.45,
#    '202102': -3.6,
#    '202103': 8.91,
#    '202104': 12.14,
#    '202105': 17.07,
#    '202106': 24.12,
#    '202107': 24.72,
#    '202108': 25.34,
#    '202109': 21.82,
#    '202110': 16.49,
#    '202111': 6.22,
#    '202112': 6.47,
#    '202113': 13.38,
#    '202201': -2.88,
#    '202202': -0.71,
#    '202203': 7.66,
#    '202204': 12.01,
#    '202205': 19.36,
#    '202206': 23.82,
#    '202207': 26.48,
#    '202208': 24.96,
#    '202209': 20.95,
#    '202210': 13.37,
#    '202211': 6.42,
#    '202212': 0.95,
#    '202213': 12.78,
#    '202301': 2.83,
#    '202302': 4.69,
#    '202303': 6.66,
#    '202304': 13.04,
#    '202305': 19.13,
#    '202306': 23.72,
#    '202307': 27.0,
#    '202308': 25.32,
#    '202309': 22.44,
#    '202310': 14.96,
#    '202311': 7.98,
#    '202312': 4.85,
#    '202313': 14.44,
#    '202401': -2.16,
#    '202402': 5.73,
#    '202403': 10.01,
#    '202404': 14.65,
#    '202405': 20.75,
#    '202406': 24.68,
#    '202407': 24.7,
#    '202408': 24.82,
#    '202409': 21.95,
#    '202410': 15.57,
#    '202411': 8.88,
#    '202412': 3.01,
#    '202413': 14.4}}}

# %%
data["times"]
# Out:
# {'data': 7.175, 'process': 0.08}

# %%
data["parameters"]["ALLSKY_SFC_SW_DWN"]
# Out:
# {'units': 'MJ/m^2/day',
#  'longname': 'All Sky Surface Shortwave Downward Irradiance'}

# %%
data["parameters"]["PRECTOTCORR"]
# Out:
# {'units': 'mm/day', 'longname': 'Precipitation Corrected'}

# %%
data["parameters"]["T2M"]
# Out:
# {'units': 'C', 'longname': 'Temperature at 2 Meters'}

# %%
data["properties"]["parameter"]
# Out:
# {'ALLSKY_SFC_SW_DWN': {'202101': 6.4,
#   '202102': 9.97,
#   '202103': 14.63,
#   '202104': 19.03,
#   '202105': 18.56,
#   '202106': 22.04,
#   '202107': 21.36,
#   '202108': 20.6,
#   '202109': 18.18,
#   '202110': 10.78,
#   '202111': 9.93,
#   '202112': 7.14,
#   '202113': 14.9,
#   '202201': 8.86,
#   '202202': 11.3,
#   '202203': 15.06,
#   '202204': 17.43,
#   '202205': 19.08,
#   '202206': 25.32,
#   '202207': 21.92,
#   '202208': 21.17,
#   '202209': 17.57,
#   '202210': 14.39,
#   '202211': 9.87,
#   '202212': 5.88,
#   '202213': 15.67,
#   '202301': 6.91,
#   '202302': 11.74,
#   '202303': 13.06,
#   '202304': 20.66,
#   '202305': 23.09,
#   '202306': 24.12,
#   '202307': 21.53,
#   '202308': 19.0,
#   '202309': 17.7,
#   '202310': 12.48,
#   '202311': 10.28,
#   '202312': 6.51,
#   '202313': 15.59,
#   '202401': 6.36,
#   '202402': 12.58,
#   '202403': 16.35,
#   '202404': 18.41,
#   '202405': 21.05,
#   '202406': 24.7,
#   '202407': 20.76,
#   '202408': 19.93,
#   '202409': 16.32,
#   '202410': 15.5,
#   '202411': 8.19,
#   '202412': 6.43,
#   '202413': 15.55},
#  'PRECTOTCORR': {'202101': 2.95,
#   '202102': 1.98,
#   '202103': 4.24,
#   '202104': 3.25,
#   '202105': 2.65,
#   '202106': 3.26,
#   '202107': 5.59,
#   '202108': 2.95,
#   '202109': 2.3,
#   '202110': 3.61,
#   '202111': 0.77,
#   '202112': 2.56,
#   '202113': 3.02,
#   '202201': 1.24,
#   '202202': 4.16,
#   '202203': 4.17,
#   '202204': 3.33,
#   '202205': 4.41,
#   '202206': 1.73,
#   '202207': 5.13,
#   '202208': 2.88,
#   '202209': 2.0,
#   '202210': 2.25,
#   '202211': 1.81,
#   '202212': 2.0,
#   '202213': 2.92,
#   '202301': 2.61,
#   '202302': 1.92,
#   '202303': 5.09,
#   '202304': 2.03,
#   '202305': 2.06,
#   '202306': 1.53,
#   '202307': 3.79,
#   '202308': 3.97,
#   '202309': 1.43,
#   '202310': 1.68,
#   '202311': 0.69,
#   '202312': 1.98,
#   '202313': 2.41,
#   '202401': 3.95,
#   '202402': 0.35,
#   '202403': 2.23,
#   '202404': 5.32,
#   '202405': 5.1,
#   '202406': 3.16,
#   '202407': 7.52,
#   '202408': 1.17,
#   '202409': 3.73,
#   '202410': 0.61,
#   '202411': 5.61,
#   '202412': 2.73,
#   '202413': 3.46},
#  'T2M': {'202101': -0.45,
#   '202102': -3.6,
#   '202103': 8.91,
#   '202104': 12.14,
#   '202105': 17.07,
#   '202106': 24.12,
#   '202107': 24.72,
#   '202108': 25.34,
#   '202109': 21.82,
#   '202110': 16.49,
#   '202111': 6.22,
#   '202112': 6.47,
#   '202113': 13.38,
#   '202201': -2.88,
#   '202202': -0.71,
#   '202203': 7.66,
#   '202204': 12.01,
#   '202205': 19.36,
#   '202206': 23.82,
#   '202207': 26.48,
#   '202208': 24.96,
#   '202209': 20.95,
#   '202210': 13.37,
#   '202211': 6.42,
#   '202212': 0.95,
#   '202213': 12.78,
#   '202301': 2.83,
#   '202302': 4.69,
#   '202303': 6.66,
#   '202304': 13.04,
#   '202305': 19.13,
#   '202306': 23.72,
#   '202307': 27.0,
#   '202308': 25.32,
#   '202309': 22.44,
#   '202310': 14.96,
#   '202311': 7.98,
#   '202312': 4.85,
#   '202313': 14.44,
#   '202401': -2.16,
#   '202402': 5.73,
#   '202403': 10.01,
#   '202404': 14.65,
#   '202405': 20.75,
#   '202406': 24.68,
#   '202407': 24.7,
#   '202408': 24.82,
#   '202409': 21.95,
#   '202410': 15.57,
#   '202411': 8.88,
#   '202412': 3.01,
#   '202413': 14.4}}

# %%
data["properties"]["parameter"].keys()
# Out:
# dict_keys(['ALLSKY_SFC_SW_DWN', 'PRECTOTCORR', 'T2M'])

# %%
data["properties"]["parameter"].values()
# Out:
# dict_values([{'202101': 6.4, '202102': 9.97, '202103': 14.63, '202104': 19.03, '202105': 18.56, '202106': 22.04, '202107': 21.36, '202108': 20.6, '202109': 18.18, '202110': 10.78, '202111': 9.93, '202112': 7.14, '202113': 14.9, '202201': 8.86, '202202': 11.3, '202203': 15.06, '202204': 17.43, '202205': 19.08, '202206': 25.32, '202207': 21.92, '202208': 21.17, '202209': 17.57, '202210': 14.39, '202211': 9.87, '202212': 5.88, '202213': 15.67, '202301': 6.91, '202302': 11.74, '202303': 13.06, '202304': 20.66, '202305': 23.09, '202306': 24.12, '202307': 21.53, '202308': 19.0, '202309': 17.7, '202310': 12.48, '202311': 10.28, '202312': 6.51, '202313': 15.59, '202401': 6.36, '202402': 12.58, '202403': 16.35, '202404': 18.41, '202405': 21.05, '202406': 24.7, '202407': 20.76, '202408': 19.93, '202409': 16.32, '202410': 15.5, '202411': 8.19, '202412': 6.43, '202413': 15.55}, {'202101': 2.95, '202102': 1.98, '202103': 4.24, '202104': 3.25, '202105': 2.65, '202106': 3.26, '202107': 5.59, '202108': 2.95, '202109': 2.3, '202110': 3.61, '202111': 0.77, '202112': 2.56, '202113': 3.02, '202201': 1.24, '202202': 4.16, '202203': 4.17, '202204': 3.33, '202205': 4.41, '202206': 1.73, '202207': 5.13, '202208': 2.88, '202209': 2.0, '202210': 2.25, '202211': 1.81, '202212': 2.0, '202213': 2.92, '202301': 2.61, '202302': 1.92, '202303': 5.09, '202304': 2.03, '202305': 2.06, '202306': 1.53, '202307': 3.79, '202308': 3.97, '202309': 1.43, '202310': 1.68, '202311': 0.69, '202312': 1.98, '202313': 2.41, '202401': 3.95, '202402': 0.35, '202403': 2.23, '202404': 5.32, '202405': 5.1, '202406': 3.16, '202407': 7.52, '202408': 1.17, '202409': 3.73, '202410': 0.61, '202411': 5.61, '202412': 2.73, '202413': 3.46}, {'202101': -0.45, '202102': -3.6, '202103': 8.91, '202104': 12.14, '202105': 17.07, '202106': 24.12, '202107': 24.72, '202108': 25.34, '202109': 21.82, '202110': 16.49, '202111': 6.22, '202112': 6.47, '202113': 13.38, '202201': -2.88, '202202': -0.71, '202203': 7.66, '202204': 12.01, '202205': 19.36, '202206': 23.82, '202207': 26.48, '202208': 24.96, '202209': 20.95, '202210': 13.37, '202211': 6.42, '202212': 0.95, '202213': 12.78, '202301': 2.83, '202302': 4.69, '202303': 6.66, '202304': 13.04, '202305': 19.13, '202306': 23.72, '202307': 27.0, '202308': 25.32, '202309': 22.44, '202310': 14.96, '202311': 7.98, '202312': 4.85, '202313': 14.44, '202401': -2.16, '202402': 5.73, '202403': 10.01, '202404': 14.65, '202405': 20.75, '202406': 24.68, '202407': 24.7, '202408': 24.82, '202409': 21.95, '202410': 15.57, '202411': 8.88, '202412': 3.01, '202413': 14.4}])

# %%
data["properties"]["parameter"]["ALLSKY_SFC_SW_DWN"]
# Out:
# {'202101': 6.4,
#  '202102': 9.97,
#  '202103': 14.63,
#  '202104': 19.03,
#  '202105': 18.56,
#  '202106': 22.04,
#  '202107': 21.36,
#  '202108': 20.6,
#  '202109': 18.18,
#  '202110': 10.78,
#  '202111': 9.93,
#  '202112': 7.14,
#  '202113': 14.9,
#  '202201': 8.86,
#  '202202': 11.3,
#  '202203': 15.06,
#  '202204': 17.43,
#  '202205': 19.08,
#  '202206': 25.32,
#  '202207': 21.92,
#  '202208': 21.17,
#  '202209': 17.57,
#  '202210': 14.39,
#  '202211': 9.87,
#  '202212': 5.88,
#  '202213': 15.67,
#  '202301': 6.91,
#  '202302': 11.74,
#  '202303': 13.06,
#  '202304': 20.66,
#  '202305': 23.09,
#  '202306': 24.12,
#  '202307': 21.53,
#  '202308': 19.0,
#  '202309': 17.7,
#  '202310': 12.48,
#  '202311': 10.28,
#  '202312': 6.51,
#  '202313': 15.59,
#  '202401': 6.36,
#  '202402': 12.58,
#  '202403': 16.35,
#  '202404': 18.41,
#  '202405': 21.05,
#  '202406': 24.7,
#  '202407': 20.76,
#  '202408': 19.93,
#  '202409': 16.32,
#  '202410': 15.5,
#  '202411': 8.19,
#  '202412': 6.43,
#  '202413': 15.55}

# %%
parameters = data["properties"]["parameter"]

# %%
df = pd.DataFrame({
    "date": list(parameters["T2M"].keys()),
    "temp_avg_c": list(parameters["T2M"].values()),
    "precipitation_mm": list(parameters["PRECTOTCORR"].values()),
    "solar_radiation": list(parameters["ALLSKY_SFC_SW_DWN"].values())
})
df
# Out:
#       date  temp_avg_c  precipitation_mm  solar_radiation
# 0   202101       -0.45              2.95             6.40
# 1   202102       -3.60              1.98             9.97
# 2   202103        8.91              4.24            14.63
# 3   202104       12.14              3.25            19.03
# 4   202105       17.07              2.65            18.56
# 5   202106       24.12              3.26            22.04
# 6   202107       24.72              5.59            21.36
# 7   202108       25.34              2.95            20.60
# 8   202109       21.82              2.30            18.18
# 9   202110       16.49              3.61            10.78
# 10  202111        6.22              0.77             9.93
# 11  202112        6.47              2.56             7.14
# 12  202113       13.38              3.02            14.90
# 13  202201       -2.88              1.24             8.86
# 14  202202       -0.71              4.16            11.30
# 15  202203        7.66              4.17            15.06
# 16  202204       12.01              3.33            17.43
# 17  202205       19.36              4.41            19.08
# 18  202206       23.82              1.73            25.32
# 19  202207       26.48              5.13            21.92
# 20  202208       24.96              2.88            21.17
# 21  202209       20.95              2.00            17.57
# 22  202210       13.37              2.25            14.39
# 23  202211        6.42              1.81             9.87
# 24  202212        0.95              2.00             5.88
# 25  202213       12.78              2.92            15.67
# 26  202301        2.83              2.61             6.91
# 27  202302        4.69              1.92            11.74
# 28  202303        6.66              5.09            13.06
# 29  202304       13.04              2.03            20.66
# 30  202305       19.13              2.06            23.09
# 31  202306       23.72              1.53            24.12
# 32  202307       27.00              3.79            21.53
# 33  202308       25.32              3.97            19.00
# 34  202309       22.44              1.43            17.70
# 35  202310       14.96              1.68            12.48
# 36  202311        7.98              0.69            10.28
# 37  202312        4.85              1.98             6.51
# 38  202313       14.44              2.41            15.59
# 39  202401       -2.16              3.95             6.36
# 40  202402        5.73              0.35            12.58
# 41  202403       10.01              2.23            16.35
# 42  202404       14.65              5.32            18.41
# 43  202405       20.75              5.10            21.05
# 44  202406       24.68              3.16            24.70
# 45  202407       24.70              7.52            20.76
# 46  202408       24.82              1.17            19.93
# 47  202409       21.95              3.73            16.32
# 48  202410       15.57              0.61            15.50
# 49  202411        8.88              5.61             8.19
# 50  202412        3.01              2.73             6.43
# 51  202413       14.40              3.46            15.55
