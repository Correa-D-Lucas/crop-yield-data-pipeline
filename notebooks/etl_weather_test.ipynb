# %% [markdown]
# #### Testing nasa_weather ETL

# %%
import pandas as pd
import sys
from pathlib import Path

# Add project root to Python path
project_root = Path().resolve().parents[1]
sys.path.append(str(project_root))

from src.api.nasa_weather import fetch_weather_data

# %%
testing_df = fetch_weather_data(lat=38.6274, lon=-90.1982, start="2021", end="2024")
testing_df
# Out:
# Requesting NASA POWER API:
# https://power.larc.nasa.gov/api/temporal/monthly/point?start=2021&end=2024&latitude=38.6274&longitude=-90.1982&community=AG&parameters=T2M%2CPRECTOTCORR%2CALLSKY_SFC_SW_DWN&format=JSON&header=true
#       date  temp_avg_c  precipitation_mm  solar_radiation
# 0   202101       -0.45              2.95             6.40
# 1   202102       -3.60              1.98             9.97
# 2   202103        8.91              4.24            14.63
# 3   202104       12.14              3.25            19.03
# 4   202105       17.07              2.65            18.56
# 5   202106       24.12              3.26            22.04
# 6   202107       24.72              5.59            21.36
# 7   202108       25.34              2.95            20.60
# 8   202109       21.82              2.30            18.18
# 9   202110       16.49              3.61            10.78
# 10  202111        6.22              0.77             9.93
# ...

# %%
testing_df.dtypes
# Out:
# date                 object
# temp_avg_c          float64
# precipitation_mm    float64
# solar_radiation     float64
# dtype: object

# %%
testing_df.isna().sum()
# Out:
# date                0
# temp_avg_c          0
# precipitation_mm    0
# solar_radiation     0
# dtype: int64

# %%
testing_df["year"] = testing_df["date"].str[0:4].astype(int)
testing_df
# Out:
#       date  temp_avg_c  precipitation_mm  solar_radiation  year  month
# 0   202101       -0.45              2.95             6.40  2021      1
# 1   202102       -3.60              1.98             9.97  2021      2
# 2   202103        8.91              4.24            14.63  2021      3
# 3   202104       12.14              3.25            19.03  2021      4
# 4   202105       17.07              2.65            18.56  2021      5
# 5   202106       24.12              3.26            22.04  2021      6
# 6   202107       24.72              5.59            21.36  2021      7
# 7   202108       25.34              2.95            20.60  2021      8
# 8   202109       21.82              2.30            18.18  2021      9
# 9   202110       16.49              3.61            10.78  2021     10
# 10  202111        6.22              0.77             9.93  2021     11
# 11  202112        6.47              2.56             7.14  2021     12
# ...

# %%
testing_df["month"] = testing_df["date"].str[4:6].astype(int)
testing_df
# Out:
#       date  temp_avg_c  precipitation_mm  solar_radiation  year  month
# 0   202101       -0.45              2.95             6.40  2021      1
# 1   202102       -3.60              1.98             9.97  2021      2
# 2   202103        8.91              4.24            14.63  2021      3
# 3   202104       12.14              3.25            19.03  2021      4
# 4   202105       17.07              2.65            18.56  2021      5
# 5   202106       24.12              3.26            22.04  2021      6
# 6   202107       24.72              5.59            21.36  2021      7
# 7   202108       25.34              2.95            20.60  2021      8
# 8   202109       21.82              2.30            18.18  2021      9
# 9   202110       16.49              3.61            10.78  2021     10
# 10  202111        6.22              0.77             9.93  2021     11
# 11  202112        6.47              2.56             7.14  2021     12
# ...

# %%
testing_df.describe()
# Out:
#        temp_avg_c  precipitation_mm  solar_radiation
# count   52.000000         52.000000         52.00000
# mean    13.689423          2.947885         15.42000
# std      9.003344          1.476054          5.55009
# min     -3.600000          0.350000          5.88000
# 25%      6.457500          1.980000         10.65500
# 50%     13.890000          2.805000         15.63000
# 75%     22.072500          3.830000         20.09750
# max     27.000000          7.520000         25.32000

# %%
df = testing_df.drop(columns=["date"])
df
# Out:
#     temp_avg_c  precipitation_mm  solar_radiation  year month
# 0        -0.45              2.95             6.40  2021    01
# 1        -3.60              1.98             9.97  2021    02
# 2         8.91              4.24            14.63  2021    03
# 3        12.14              3.25            19.03  2021    04
# 4        17.07              2.65            18.56  2021    05
# 5        24.12              3.26            22.04  2021    06
# 6        24.72              5.59            21.36  2021    07
# 7        25.34              2.95            20.60  2021    08
# 8        21.82              2.30            18.18  2021    09
# 9        16.49              3.61            10.78  2021    10
# 10        6.22              0.77             9.93  2021    11
# 11        6.47              2.56             7.14  2021    12
# 12       13.38              3.02            14.90  2021    13
# 13       -2.88              1.24             8.86  2022    01
# ...

# %%
testing_df.dtypes
# Out:
# date                 object
# temp_avg_c          float64
# precipitation_mm    float64
# solar_radiation     float64
# year                  int64
# month                 int64
# dtype: object

# %%
df["month"] = df["month"].astype(int)

# %%
df["year"] = df["year"].astype(int)

# %%
df.dtypes
# Out:
# temp_avg_c          float64
# precipitation_mm    float64
# solar_radiation     float64
# year                  int64
# month                 int64
# dtype: object

# %%
df = df.query("month <= 12")
df
# Out:
#     temp_avg_c  precipitation_mm  solar_radiation  year  month
# 0        -0.45              2.95             6.40  2021      1
# 1        -3.60              1.98             9.97  2021      2
# 2         8.91              4.24            14.63  2021      3
# 3        12.14              3.25            19.03  2021      4
# 4        17.07              2.65            18.56  2021      5
# 5        24.12              3.26            22.04  2021      6
# 6        24.72              5.59            21.36  2021      7
# 7        25.34              2.95            20.60  2021      8
# 8        21.82              2.30            18.18  2021      9
# 9        16.49              3.61            10.78  2021     10
# 10        6.22              0.77             9.93  2021     11
# 11        6.47              2.56             7.14  2021     12
# 13       -2.88              1.24             8.86  2022      1
# 14       -0.71              4.16            11.30  2022      2
# ...

# %%
from sqlalchemy import create_engine

def engine_call(user:str, password:str, host:str, port:str, database:str):


    engine = create_engine(
    f"postgresql://{user}:{password}@{host}:{port}/{database}"
    )
    return engine 

print(engine_call(user="lucas", password="?", host="xxxx", port="5412", database="base_data"))
# Out:
# Engine(postgresql://lucas:***@xxxx:5412/base_data)

# %% [markdown]
# ##### engine works
